# %%
library(tidyverse)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
load("./ICPSR_38779/DS0001/38779-0001-Data.rda")

# %%
# load("./ICPSR_38740/DS0001/38740-0001-Data.rda")

# load("./ICPSR_38743/DS0001/38743-0001-Data.rda")

# %%
names(da38779.0001)
# Out:
#  [1] "ASR_ID"   "CONTENTS" "STATE"    "ORI"      "GROUP"    "DIV"
#  [7] "AGHEADER" "YEAR"     "MSA"      "COUNTY"   "SEQNO"    "SUB"
# [13] "CORE"     "COVBY"    "POP"      "AGENCY"   "STNAME"   "MONTH"
# [19] "MOHEADER" "BREAK"    "AREO"     "ZERO"     "DTLASTUP" "DTPRUP1"
# [25] "DTPRUP2"  "JUVDISP"  "JDHANDDP" "JDREFJC"  "JDREFWA"  "JDREFOPA"
# [31] "JDREFCC"  "OFFENSE"  "OCCUR"    "M0_9"     "M10_12"   "M13_14"
# [37] "M15"      "M16"      "M17"      "M18"      "M19"      "M20"
# [43] "M21"      "M22"      "M23"      "M24"      "M25_29"   "M30_34"
# [49] "M35_39"   "M40_44"   "M45_49"   "M50_54"   "M55_59"   "M60_64"
# [55] "M65"      "F0_9"     "F10_12"   "F13_14"   "F15"      "F16"
# [61] "F17"      "F18"      "F19"      "F20"      "F21"      "F22"
# [67] "F23"      "F24"      "F25_29"   "F30_34"   "F35_39"   "F40_44"
# [73] "F45_49"   "F50_54"   "F55_59"   "F60_64"   "F65"      "AW"
# [79] "AB"       "AI"       "AA"       "JW"       "JB"       "JI"
# ...

# %%
da1 = da38779.0001[,c(3, 8, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89)]

# %%
# names(da38740.0001)

# names(da38743.0001)

# final <- list(da38779.0001, da38740.0001, da38743.0001)

# final = final[c(3, 8, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89)]

# %%
summary(da1)
# Out:
#                STATE             YEAR            AW                AB
#  (04) California  :117232   Min.   :2019   Min.   :   0.00   Min.   :   0.0
#  (42) Texas       : 98576   1st Qu.:2019   1st Qu.:   1.00   1st Qu.:   0.0
#  (37) Pennsylvania: 85692   Median :2019   Median :   2.00   Median :   1.0
#  (29) New Jersey  : 60935   Mean   :2019   Mean   :   5.38   Mean   :   2.8
#  (31) New York    : 48869   3rd Qu.:2019   3rd Qu.:   4.00   3rd Qu.:   2.0
#  (21) Michigan    : 47643   Max.   :2019   Max.   :2043.00   Max.   :1321.0
#  (Other)          :897078                  NA's   :118057    NA's   :433551
#        AI               AA               JW               JB
#  Min.   :  0.0    Min.   :  0.0    Min.   :  0.0    Min.   :  0.0
#  1st Qu.:  0.0    1st Qu.:  0.0    1st Qu.:  0.0    1st Qu.:  0.0
#  Median :  0.0    Median :  0.0    Median :  0.0    Median :  0.0
#  Mean   :  0.3    Mean   :  0.2    Mean   :  0.6    Mean   :  0.3
# ...

# %%
dim(da1)
# Out:
# [1] 1356025      14

# %%
da1.no_na <- na.omit(da1)

# %%
Reduce(function(x, y) merge(x, y, all=TRUE), final)  

write.csv(final, './final.csv')

# %%
da38779.0001
# Out:
#         ASR_ID              CONTENTS               STATE        ORI       GROUP
# 1       (3) ASR Master File (3) Detail record      (50) Alaska  AK00101   1C
# 2       (3) ASR Master File (3) Detail record      (50) Alaska  AK00101   1C
# 3       (3) ASR Master File (3) Detail record      (50) Alaska  AK00101   1C
# 4       (3) ASR Master File (3) Detail record      (50) Alaska  AK00101   1C
# 5       (3) ASR Master File (3) Detail record      (50) Alaska  AK00101   1C
# 6       (3) ASR Master File (3) Detail record      (50) Alaska  AK00101   1C
# 7       (3) ASR Master File (3) Detail record      (50) Alaska  AK00101   1C
# 8       (3) ASR Master File (3) Detail record      (50) Alaska  AK00101   1C
# 9       (3) ASR Master File (3) Detail record      (50) Alaska  AK00101   1C
# 10      (3) ASR Master File (3) Detail record      (50) Alaska  AK00101   1C
# 11      (3) ASR Master File (3) Detail record      (50) Alaska  AK00101   1C
# ...

# %%
da38740.0001
# Out:
#         ASR_ID              CONTENTS               STATE        ORI       GROUP
# 1       (3) ASR Master File (3) Detail record      (50) Alaska  AK00101   1C
# 2       (3) ASR Master File (3) Detail record      (50) Alaska  AK00101   1C
# 3       (3) ASR Master File (3) Detail record      (50) Alaska  AK00101   1C
# 4       (3) ASR Master File (3) Detail record      (50) Alaska  AK00101   1C
# 5       (3) ASR Master File (3) Detail record      (50) Alaska  AK00101   1C
# 6       (3) ASR Master File (3) Detail record      (50) Alaska  AK00101   1C
# 7       (3) ASR Master File (3) Detail record      (50) Alaska  AK00101   1C
# 8       (3) ASR Master File (3) Detail record      (50) Alaska  AK00101   1C
# 9       (3) ASR Master File (3) Detail record      (50) Alaska  AK00101   1C
# 10      (3) ASR Master File (3) Detail record      (50) Alaska  AK00101   1C
# 11      (3) ASR Master File (3) Detail record      (50) Alaska  AK00101   1C
# ...

# %%
da38743.0001
# Out:
#         ASR_ID              CONTENTS               STATE        ORI       GROUP
# 1       (3) ASR Master File (3) Detail record      (50) Alaska  AK00101   1C
# 2       (3) ASR Master File (3) Detail record      (50) Alaska  AK00101   1C
# 3       (3) ASR Master File (3) Detail record      (50) Alaska  AK00101   1C
# 4       (3) ASR Master File (3) Detail record      (50) Alaska  AK00101   1C
# 5       (3) ASR Master File (3) Detail record      (50) Alaska  AK00101   1C
# 6       (3) ASR Master File (3) Detail record      (50) Alaska  AK00101   1C
# 7       (3) ASR Master File (3) Detail record      (50) Alaska  AK00101   1C
# 8       (3) ASR Master File (3) Detail record      (50) Alaska  AK00101   1C
# 9       (3) ASR Master File (3) Detail record      (50) Alaska  AK00101   1C
# 10      (3) ASR Master File (3) Detail record      (50) Alaska  AK00101   1C
# 11      (3) ASR Master File (3) Detail record      (50) Alaska  AK00101   1C
# ...

# %%
getwd()
# Out:
# [1] "/Users/ivanshukaushik/Desktop/Fall 23/Regresion and Time Series/code/ICPSR_38779"

# %%
da38779.0001
# Out:
#         ASR_ID              CONTENTS               STATE        ORI       GROUP
# 1       (3) ASR Master File (3) Detail record      (50) Alaska  AK00101   1C
# 2       (3) ASR Master File (3) Detail record      (50) Alaska  AK00101   1C
# 3       (3) ASR Master File (3) Detail record      (50) Alaska  AK00101   1C
# 4       (3) ASR Master File (3) Detail record      (50) Alaska  AK00101   1C
# 5       (3) ASR Master File (3) Detail record      (50) Alaska  AK00101   1C
# 6       (3) ASR Master File (3) Detail record      (50) Alaska  AK00101   1C
# 7       (3) ASR Master File (3) Detail record      (50) Alaska  AK00101   1C
# 8       (3) ASR Master File (3) Detail record      (50) Alaska  AK00101   1C
# 9       (3) ASR Master File (3) Detail record      (50) Alaska  AK00101   1C
# 10      (3) ASR Master File (3) Detail record      (50) Alaska  AK00101   1C
# 11      (3) ASR Master File (3) Detail record      (50) Alaska  AK00101   1C
# ...

# %%
colnames(da38779.0001)
# Out:
#  [1] "ASR_ID"   "CONTENTS" "STATE"    "ORI"      "GROUP"    "DIV"
#  [7] "AGHEADER" "YEAR"     "MSA"      "COUNTY"   "SEQNO"    "SUB"
# [13] "CORE"     "COVBY"    "POP"      "AGENCY"   "STNAME"   "MONTH"
# [19] "MOHEADER" "BREAK"    "AREO"     "ZERO"     "DTLASTUP" "DTPRUP1"
# [25] "DTPRUP2"  "JUVDISP"  "JDHANDDP" "JDREFJC"  "JDREFWA"  "JDREFOPA"
# [31] "JDREFCC"  "OFFENSE"  "OCCUR"    "M0_9"     "M10_12"   "M13_14"
# [37] "M15"      "M16"      "M17"      "M18"      "M19"      "M20"
# [43] "M21"      "M22"      "M23"      "M24"      "M25_29"   "M30_34"
# [49] "M35_39"   "M40_44"   "M45_49"   "M50_54"   "M55_59"   "M60_64"
# [55] "M65"      "F0_9"     "F10_12"   "F13_14"   "F15"      "F16"
# [61] "F17"      "F18"      "F19"      "F20"      "F21"      "F22"
# [67] "F23"      "F24"      "F25_29"   "F30_34"   "F35_39"   "F40_44"
# [73] "F45_49"   "F50_54"   "F55_59"   "F60_64"   "F65"      "AW"
# [79] "AB"       "AI"       "AA"       "JW"       "JB"       "JI"
# ...

# %%
da38779.0001 = da38779.0001[, -c(1, 2, 4)]

# %%
head(da38779.0001)
# Out:
#   STATE       GROUP DIV         AGHEADER                  YEAR MSA COUNTY SEQNO
# 1 (50) Alaska 1C    (9) Pacific (0) Agency header present 2019 38  0      0
# 2 (50) Alaska 1C    (9) Pacific (0) Agency header present 2019 38  0      0
# 3 (50) Alaska 1C    (9) Pacific (0) Agency header present 2019 38  0      0
# 4 (50) Alaska 1C    (9) Pacific (0) Agency header present 2019 38  0      0
# 5 (50) Alaska 1C    (9) Pacific (0) Agency header present 2019 38  0      0
# 6 (50) Alaska 1C    (9) Pacific (0) Agency header present 2019 38  0      0
#   SUB              CORE ⋯ AI AA JW JB JI JA AH AN JH JN
# 1 (0) Non-Suburban Y    ⋯  0 0  0  0  0  0  NA NA NA NA
# 2 (0) Non-Suburban Y    ⋯  0 1  0  0  0  0  NA NA NA NA
# 3 (0) Non-Suburban Y    ⋯  1 0  0  0  0  0  NA NA NA NA
# 4 (0) Non-Suburban Y    ⋯  6 2  0  0  0  0  NA NA NA NA
# 5 (0) Non-Suburban Y    ⋯ 36 4  1  0  5  0  NA NA NA NA
# 6 (0) Non-Suburban Y    ⋯  5 1  0  0  2  0  NA NA NA NA
